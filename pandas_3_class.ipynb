...
# 1703     Zimbabwe  2007    12311143    Africa    43.487    469.709298
# 851   Korea, Rep.  2007    49044790      Asia    78.623  23348.139730
# 1691       Zambia  2007    11746035    Africa    42.384   1271.211593
# 1705    Sri Lanka  2022   130000000      Asia    80.000    500.000000
# 1706    Sri Lanka  2022   130000000      Asia    80.000    500.000000
#
# [1708 rows x 6 columns]

# %%
df.sort_values(by="year",ascending=False)
# Out:
#                        country  year  population continent  life_exp  \
# 1705                 Sri Lanka  2022   130000000      Asia    80.000
# 1706                 Sri Lanka  2022   130000000      Asia    80.000
# 1691                    Zambia  2007    11746035    Africa    42.384
# 11                 Afghanistan  2007    31889923      Asia    43.828
# 503                    Eritrea  2007     4906585    Africa    58.040
# ...                        ...   ...         ...       ...       ...
# 996                   Mongolia  1952      800663      Asia    42.244
# 252   Central African Republic  1952     1291695    Africa    35.463
# 36                      Angola  1952     4232095    Africa    30.015
# 1692                  Zimbabwe  1952     3080907    Africa    48.451
# 0                  Afghanistan  1952     8425333      Asia    28.801
#
#           gdp_cap
# 1705   500.000000
# 1706   500.000000
# 1691  1271.211593
# 11     974.580338
# 503    641.369524
# ...           ...
# ...

# %%
#multiple columns
df.sort_values(by=['year','life_exp'])
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 552             Gambia  1952      284320    Africa    30.000    485.230659
# 36              Angola  1952     4232095    Africa    30.015   3520.610273
# 1344      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# 1032        Mozambique  1952     6446316    Africa    31.286    468.526038
# ...                ...   ...         ...       ...       ...           ...
# 695            Iceland  2007      301931    Europe    81.757  36180.789190
# 671   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 803              Japan  2007   127467972      Asia    82.603  31656.068060
# 1705         Sri Lanka  2022   130000000      Asia    80.000    500.000000
# 1706         Sri Lanka  2022   130000000      Asia    80.000    500.000000
#
# [1708 rows x 6 columns]

# %%
df.sort_values(by=['year','life_exp'],ascending=[True,False])
# Out:
#           country  year  population continent  life_exp       gdp_cap
# 1140       Norway  1952     3327728    Europe    72.670  10095.421720
# 684       Iceland  1952      147962    Europe    72.490   7267.688428
# 1080  Netherlands  1952    10381988    Europe    72.130   8941.571858
# 1464       Sweden  1952     7124673    Europe    71.860   8527.844662
# 408       Denmark  1952     4334000    Europe    70.780   9692.385245
# ...           ...   ...         ...       ...       ...           ...
# 1691       Zambia  2007    11746035    Africa    42.384   1271.211593
# 1043   Mozambique  2007    19951656    Africa    42.082    823.685621
# 1463    Swaziland  2007     1133066    Africa    39.613   4513.480643
# 1705    Sri Lanka  2022   130000000      Asia    80.000    500.000000
# 1706    Sri Lanka  2022   130000000      Asia    80.000    500.000000
#
# [1708 rows x 6 columns]

# %% [markdown]
# Concatenation

# %%
users = pd.DataFrame({"userid":[1, 2, 3], "name":["sharadh", "shahid", "khusalli"]})
users
# Out:
#    userid      name
# 0       1   sharadh
# 1       2    shahid
# 2       3  khusalli

# %%
msgs = pd.DataFrame({"userid":[1, 1, 2, 4], "msg":['hmm', "acha", "theek hai", "nice"]})
msgs
# Out:
#    userid        msg
# 0       1        hmm
# 1       1       acha
# 2       2  theek hai
# 3       4       nice

# %%
pd.concat([users,msgs],axis=0)
# Out:
#    userid      name        msg
# 0       1   sharadh        NaN
# 1       2    shahid        NaN
# 2       3  khusalli        NaN
# 0       1       NaN        hmm
# 1       1       NaN       acha
# 2       2       NaN  theek hai
# 3       4       NaN       nice

# %%
pd.concat([users,msgs],axis=1)
# Out:
#    userid      name  userid        msg
# 0     1.0   sharadh       1        hmm
# 1     2.0    shahid       1       acha
# 2     3.0  khusalli       2  theek hai
# 3     NaN       NaN       4       nice

# %%
df1=pd.DataFrame({'A':['apple','banana'],
                   'B':['x','y']})

# %%
df2=pd.DataFrame({'A':['mango','orange'],
                  'B':['p','q']})

# %%
pd.concat([df1,df2],axis=0)
# Out:
#         A  B
# 0   apple  x
# 1  banana  y
# 0   mango  p
# 1  orange  q

# %%
pd.concat([df1,df2],axis=1)
# Out:
#         A  B       A  B
# 0   apple  x   mango  p
# 1  banana  y  orange  q

# %% [markdown]
# Merge

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
pd.merge(users,msgs,on="userid",how="inner")
# Out:
#    userid     name        msg
# 0       1  sharadh        hmm
# 1       1  sharadh       acha
# 2       2   shahid  theek hai

# %%
pd.merge(users,msgs,on="userid",how="left")
# Out:
#    userid      name        msg
# 0       1   sharadh        hmm
# 1       1   sharadh       acha
# 2       2    shahid  theek hai
# 3       3  khusalli        NaN

# %%
pd.merge(users,msgs,on="userid",how="right")
# Out:
#    userid     name        msg
# 0       1  sharadh        hmm
# 1       1  sharadh       acha
# 2       2   shahid  theek hai
# 3       4      NaN       nice

# %%
pd.merge(users,msgs,on="userid",how="outer")
# Out:
#    userid      name        msg
# 0       1   sharadh        hmm
# 1       1   sharadh       acha
# 2       2    shahid  theek hai
# 3       3  khusalli        NaN
# 4       4       NaN       nice

# %%
temp_df = pd.merge(users, msgs, on="userid", how="inner")
print(temp_df)
# Out:
#    userid     name        msg
# 0       1  sharadh        hmm
# 1       1  sharadh       acha
# 2       2   shahid  theek hai

# %%
pd.merge(temp_df,msgs,on="userid",how="outer")
# Out:
#    userid     name      msg_x      msg_y
# 0       1  sharadh        hmm        hmm
# 1       1  sharadh        hmm       acha
# 2       1  sharadh       acha        hmm
# 3       1  sharadh       acha       acha
# 4       2   shahid  theek hai  theek hai
# 5       4      NaN        NaN       nice

# %% [markdown]
# users.columns
# index(['userid', 'name'], dtype='object')

# %%
users
# Out:
#    id      name
# 0   1   sharadh
# 1   2    shahid
# 2   3  khusalli

# %%
users.columns=['id', 'name']

# %%
msgs
# Out:
#    userid        msg
# 0       1        hmm
# 1       1       acha
# 2       2  theek hai
# 3       4       nice

# %%
pd.merge(users,msgs,left_on="id",right_on="userid",how="inner")
# Out:
#    id     name  userid        msg
# 0   1  sharadh       1        hmm
# 1   1  sharadh       1       acha
# 2   2   shahid       2  theek hai

# %%
tempp_df=pd.merge(users,msgs,left_on="id",right_on="userid",how="left")

# %%
tempp_df
# Out:
#    id      name  userid        msg
# 0   1   sharadh     1.0        hmm
# 1   1   sharadh     1.0       acha
# 2   2    shahid     2.0  theek hai
# 3   3  khusalli     NaN        NaN

# %%
mask=tempp_df["msg"].isnull()

# %%
tempp_df[mask]
# Out:
#    id      name  userid  msg
# 3   3  khusalli     NaN  NaN

# %% [markdown]
# ###Movie Dataset###

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 3.22MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 3.83MB/s]

# %%
movies = pd.read_csv('movies.csv')

# %%
movies.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
movies.drop(columns="Unnamed: 0",inplace=True)

# %%
movies.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 4         4767  2007   May   Tuesday

# %%
movies.shape
# Out:
# (1465, 11)

# %%
directors=pd.read_csv("directors.csv")

# %%
directors.head()
# Out:
#    Unnamed: 0      director_name    id gender
# 0           0      James Cameron  4762   Male
# 1           1     Gore Verbinski  4763   Male
# 2           2         Sam Mendes  4764   Male
# 3           3  Christopher Nolan  4765   Male
# 4           4     Andrew Stanton  4766   Male

# %%
directors.drop(columns="Unnamed: 0", inplace = True)
directors.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
movies.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 4         4767  2007   May   Tuesday

# %%
directors.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
# How many unique directors i have in my movies df?
movies["director_id"].nunique()
# Out:
# 199

# %%
directors["id"].nunique()
# Out:
# 2349

# %%
# How can we check if all director_id values are present in id?
movies['director_id'].isin(directors['id'])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1460    True
# 1461    True
# 1462    True
# 1463    True
# 1464    True
# Name: director_id, Length: 1465, dtype: bool

# %%
import numpy as np
np.all(movies['director_id'].isin(directors['id']))
# Out:
# np.True_

# %%
data = pd.merge(movies, directors, left_on = 'director_id', right_on = 'id', how="left")

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...
